# %%
def user_info(name,age):
    """
    this function take name and age from user and return again
    :param_1: take  the name of user from input user interface 
    type param_1 : str
    :param_2: take  the name of user from input user interface
    type param_1 : int
    
    return:this function will print the name and the age 
    rtype : str , int 
    
    """
    return f"My Name is {name} , My Age is {age}"

# %%
user_info("Basmala",20)
# Out:
# 'My Name is Basmala , My Age is 20'

# %%
user_info(20,"Basmala")
# Out:
# 'My Name is 20 , My Age is Basmala'

# %%
user_info(age = 20, name= "Basmala")
# Out:
# 'My Name is Basmala , My Age is 20'

# %%
def user_info(* name) :
    """
    
    """
    print (name)
    print(type(name))

# %%
user_info ("depi","Python",5,2.5,True,[1,2,3])
# Out:
# ('depi', 'Python', 5, 2.5, True, [1, 2, 3])
# <class 'tuple'>

# %%
x ="Basmala"
y = 90
"{0},{1}".format(x,y)
# Out:
# 'Basmala,90'

# %%
def user_info (**name):
    print(name)  
    print(type(name))
    user_info(key1 =10.5,key2 = 2)

# %%
print(user_info)
# Out:
# <function user_info at 0x0000016674973560>

# %%
result = lambda x:x+10
print(type(result))
# Out:
# <class 'function'>

# %%
function_name = lambda x,y:x+y 
print(function_name(5,10))
# Out:
# 15

# %%
def function_1 (n):
    return lambda a:a*n
function_2 = function_1(2)
print(function_2(11))
# Out:
# 22

# %%
def fun(x) :
    print("inside :", x)
    fun(3)
    print("outside :", x)

# %%
x = "global"
def outer_fun():
    x = "outer_local"
    def inner_fun():
        global x
        x = "changed"
        print("inside inner func",x)
        inner_fun()
        print("inside outer fun:",x)
        outer_fun()
        print("outside any func:" , x)

# %%
x = int(input())
y = int(input())
try:
    5/0
except Exception as e: 
    print(e)
# Out:
# division by zero

# %%
try :
    x = 10
    y = int (input())
    x/y
except:
    print("Division by zero")
finally:
    print("Done !")
# Out:
# Division by zero
# Done !

# %%
from random import randint
randint(0,10)
# Out:
# 9
