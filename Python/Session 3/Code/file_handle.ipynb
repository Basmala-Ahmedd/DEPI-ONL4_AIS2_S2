# %%
import os

# %%
base_dire ="E:/DEBI-ONL4_AIS2_S2/DEBI-ONL4_AIS2_S2/Python/Session 3/Code/File_handle"

# %%
file_name = os.listdir(base_dire)
print(type(file_name))
file_name
# Out:
# <class 'list'>
# ['Files', 'test']

# %%
base_dire ="./File_handle"
file_name = "test.txt"
file_path = os.path.join(base_dire,file_name)
file_name
# Out:
# 'test.txt'

# %%
import os
dir = "E:/DEBI-ONL4_AIS2_S2/DEBI-ONL4_AIS2_S2/Python/Session 3/Code/File_handle/Files"
for i in range(20) :
    inner_path = os.path.join(dir,"dir"+str(i))
if not os.path.exists(inner_path):
    os.makedirs(inner_path)

# %%
with open ("./File_handle/test","a+") as file:
    file .write("New Line added \n")
    file.seek(0) # Move The File Pointer To The Beginning  
    updated_content = file.read()
    print(updated_content)
# Out:
# New Line added

# %%
f = open("test2.txt","a")
f.write("Hello\n")
f.close()
